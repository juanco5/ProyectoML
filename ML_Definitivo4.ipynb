# %%
# importing librarires
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
#Importamos la base de datos
df = pd.read_csv(r'C:\Users\juanc\Desktop\proyecto ML\proyecto machine learning\3-Machine-Learning\Entregas\ML_project\salaries _2.csv')
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 0       120000             USD         120000                 AU
# 1        70000             USD          70000                 AU
# 2       130000             USD         130000                 US
# 3       110000             USD         110000                 US
# 4       240000             USD         240000                 US
# ...        ...             ...            ...                ...
# 16489   412000             USD         412000                 US
# 16490   151000             USD         151000                 US
# 16491   105000             USD         105000                 US
# 16492   100000             USD         100000                 US
# 16493  7000000             INR          94665                 IN
#
#        remote_ratio company_location company_size
# 0                 0               AU            S
# 1                 0               AU            S
# 2                 0               US            M
# 3                 0               US            M
# 4                 0               US            M
# ...             ...              ...          ...
# 16489           100               US            L
# 16490           100               US            L
# 16491           100               US            S
# 16492           100               US            L
# 16493            50               IN            L
#
# [16494 rows x 11 columns]

# %% [markdown]
# ## **Análisis exploratorio de los datos**

# %%
df.head()
# Out:
#    work_year experience_level employment_type             job_title  salary  \
# 0       2024               MI              FT        Data Scientist  120000
# 1       2024               MI              FT        Data Scientist   70000
# 2       2024               MI              CT        Data Scientist  130000
# 3       2024               MI              CT        Data Scientist  110000
# 4       2024               MI              FT  Data Science Manager  240000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         120000                 AU             0
# 1             USD          70000                 AU             0
# 2             USD         130000                 US             0
# 3             USD         110000                 US             0
# 4             USD         240000                 US             0
#
#   company_location company_size
# 0               AU            S
# 1               AU            S
# 2               US            M
# 3               US            M
# 4               US            M

# %%
df.info()
#No hay ningun NAN. 
#Para el analisis posterior sera necesario pasar alguna columna de obj a numerica
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16494 entries, 0 to 16493
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16494 non-null  int64
#  1   experience_level    16494 non-null  object
#  2   employment_type     16494 non-null  object
#  3   job_title           16494 non-null  object
#  4   salary              16494 non-null  int64
#  5   salary_currency     16494 non-null  object
#  6   salary_in_usd       16494 non-null  int64
#  7   employee_residence  16494 non-null  object
#  8   remote_ratio        16494 non-null  int64
#  9   company_location    16494 non-null  object
#  10  company_size        16494 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  16494.000000  1.649400e+04   16494.000000  16494.000000
# mean    2023.224991  1.637878e+05  149713.575725     32.044986
# std        0.713405  3.406017e+05   68516.136918     46.260201
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.020000e+05  101517.500000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.873422e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %% [markdown]
# ***Eliminamos las columnas que no nos hagan falta***

# %%
df = df.drop(columns=['salary_currency', 'salary'])
#la columna salary_currency, salary y salary_in_usd dice lo mismo asi que me quedo unicamente con salary_in_usd

# %% [markdown]
# ### **Pasamos las columnas de type object a int, antes de esto analizamos cada columna si tiene mas sentido pasarlo a binario o continua**

# %% [markdown]
# #### 1. Columna Experiencie_level

# %%
sns.boxplot(x='experience_level', y='salary_in_usd', data=df)
#en=entry, mi=middle, se=senior, ex=Executive-level / Director
#vemos que a mayor experiencia mayor sueldo por lo que tiene sentido pasarlo a una variable continua
# Out:
# <Axes: xlabel='experience_level', ylabel='salary_in_usd'>

# %%
df['is_outlier'] = df.groupby('experience_level').apply(lambda x: ((x['salary_in_usd'] < x['salary_in_usd'].quantile(0.25)) | (x['salary_in_usd'] > x['salary_in_usd'].quantile(0.75))).astype(int)).reset_index(level=0, drop=True)
#vemos que hay bastante outliers por lo que vamos a crear una nueva columna con indicando si son outliers o no para tratarlos de forma separada
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_16264\2682282886.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df['is_outlier'] = df.groupby('experience_level').apply(lambda x: ((x['salary_in_usd'] < x['salary_in_usd'].quantile(0.25)) | (x['salary_in_usd'] > x['salary_in_usd'].quantile(0.75))).astype(int)).reset_index(level=0, drop=True)

# %%
df.head()
# Out:
#    work_year experience_level employment_type             job_title  \
# 0       2024               MI              FT        Data Scientist
# 1       2024               MI              FT        Data Scientist
# 2       2024               MI              CT        Data Scientist
# 3       2024               MI              CT        Data Scientist
# 4       2024               MI              FT  Data Science Manager
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0         120000                 AU             0               AU
# 1          70000                 AU             0               AU
# 2         130000                 US             0               US
# 3         110000                 US             0               US
# 4         240000                 US             0               US
#
#   company_size  is_outlier
# 0            S           0
# 1            S           1
# 2            M           0
# 3            M           0
# 4            M           1

# %%
count_outliers = df[df['is_outlier'] == 0]['company_location'].value_counts()
count_outliers
# Out:
# company_location
# US    7798
# CA     226
# GB     209
# DE      37
# AU      25
# FR      16
# NL      10
# ES       8
# NZ       7
# IE       6
# CO       5
# CH       5
# PR       4
# LT       4
# IN       3
# MX       3
# PL       2
# SA       2
# JP       2
# EG       2
# SG       2
# LB       2
# GR       2
# IL       2
# BE       2
# PT       2
# AE       1
# DZ       1
# IQ       1
# RU       1
# BR       1
# CN       1
# NG       1
# PH       1
# AT       1
# IR       1
# HR       1
# SE       1
# MU       1
# ZA       1
# VN       1
# MT       1
# LV       1
# LU       1
# Name: count, dtype: int64

# %%
# Pasar la columna de str a int
df['experience_level'] = df['experience_level'].replace({'EN': 1, 'MI': 2, 'SE': 3, 'EX': 4})
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_16264\3770702301.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['experience_level'] = df['experience_level'].replace({'EN': 1, 'MI': 2, 'SE': 3, 'EX': 4})

# %% [markdown]
# #### 2. Columna Company_location

# %%
company_location_counts =df['company_location'].value_counts()
# Identificar los paises que aparecen menos de 30 veces
company_location_remove = company_location_counts[company_location_counts < 30].index

# Eliminar las filas correspondientes a estos países, ya que estos son demasiados excasos para ser representativos
df = df[~df['company_location'].isin(company_location_remove)]
#solo nos quedamos las que almenos sean 30
#us esta sobrepresentado hay que disminuirlo
company_location_counts
# Out:
# company_location
# US    14478
# GB      694
# CA      455
# ES      133
# DE      105
#       ...
# AM        1
# QA        1
# AD        1
# EC        1
# MD        1
# Name: count, Length: 77, dtype: int64

# %%
# Filtrar el DataFrame para mantener solo las filas donde 'company_location' es 'US'
df = df[df['company_location'] == 'US']

# %%
df = df.drop(columns=['company_location'])

# %% [markdown]
# #### 3. Columna Employment_type

# %%
sns.boxplot(x='employment_type', y='salary_in_usd', data=df)
#FL=freelance, pt=part time, ct=contrato por proyecto, ft=fulltime
# Out:
# <Axes: xlabel='employment_type', ylabel='salary_in_usd'>

# %%
df['employment_type'].value_counts()
#Elimino todos los que no sean FT del resto hay muy pocos datos
# Out:
# employment_type
# FT    14429
# PT       26
# CT       19
# FL        4
# Name: count, dtype: int64

# %%
# Especificar los valores a eliminar
employment_type_remove = ['PT', 'CT', 'FL']

# Eliminar las filas que tienen esos valores en la columna 'employment_type'
df = df.drop(df[df['employment_type'].isin(employment_type_remove)].index)

#Como solo me queda FT en la columna esta ya no me aporta informacion alguna y podemos eliminarla
df = df.drop(columns=['employment_type'])

# %% [markdown]
# #### 4. Columna Job_title

# %%
job_title_counts = df['job_title'].value_counts()
#Considero que todos los trabajos en los que tenga menos de 50 personas no hay data suficiente y el resultado puede estar muy sesgado por el azar por lo que los elimino

# %%
# Identificar los trabajos que aparecen menos de 50 veces
job_title_remove = job_title_counts[job_title_counts < 50].index

# Eliminar las filas correspondientes a estos países, ya que estos son demasiados excasos para ser representativos
df = df[~df['job_title'].isin(job_title_remove)]

# %%
df['job_title'].value_counts()
#las que tienen 50-100 counts no las eliminamos porque vemos que muchas son puestos de manager/jefe por lo que tiene sentido que haya menos pero esa informacion nos es relevante mantenerla
# Out:
# job_title
# Data Engineer                     3075
# Data Scientist                    2863
# Data Analyst                      2143
# Machine Learning Engineer         1506
# Research Scientist                 496
# Applied Scientist                  428
# Data Architect                     391
# Analytics Engineer                 370
# Research Engineer                  279
# Data Science                       248
# Business Intelligence Engineer     236
# Data Manager                       192
# ML Engineer                        177
# Business Intelligence Analyst      158
# Machine Learning Scientist         116
# Data Science Manager               113
# Research Analyst                   111
# AI Engineer                         99
# Business Intelligence               96
# Data Specialist                     74
# BI Developer                        73
# Data Science Consultant             71
# Data Analytics Manager              59
# Data Modeler                        50
# Name: count, dtype: int64

# %%
# Establece el estilo de Seaborn
sns.set(style="whitegrid")

# Crea el gráfico de caja
sns.boxplot(x='job_title', y='salary_in_usd', data=df)

# Rota los nombres del eje x en vertical
plt.xticks(rotation=90)

# Muestra el gráfico
plt.show()

# %%
df.groupby('job_title').mean('salary_in_usd')
# Out:
#                                   work_year  experience_level  salary_in_usd  \
# job_title
# AI Engineer                     2023.626263          2.727273  173346.212121
# Analytics Engineer              2023.218919          2.762162  163965.872973
# Applied Scientist               2023.264019          2.703271  190896.334112
# BI Developer                    2023.260274          2.452055  113973.109589
# Business Intelligence           2024.000000          2.666667  143816.677083
# Business Intelligence Analyst   2023.582278          2.189873  121916.436709
# Business Intelligence Engineer  2023.338983          2.864407  143317.707627
# Data Analyst                    2023.238917          2.362109  112006.359776
# Data Analytics Manager          2023.135593          2.322034  138081.474576
# Data Architect                  2023.276215          2.961637  165810.554987
# Data Engineer                   2023.163902          2.754146  153216.048780
# Data Manager                    2023.281250          2.531250  111101.130208
# Data Modeler                    2023.480000          2.840000  134303.500000
# Data Science                    2023.846774          2.798387  169539.552419
# Data Science Consultant         2023.295775          2.830986  115773.239437
# Data Science Manager            2022.867257          2.769912  201293.699115
# Data Scientist                  2023.212015          2.717429  162916.578764
# Data Specialist                 2023.175676          2.243243   95471.621622
# ML Engineer                     2023.299435          2.751412  200486.265537
# Machine Learning Engineer       2023.297477          2.832669  195747.610226
# Machine Learning Scientist      2023.275862          2.750000  194910.724138
# Research Analyst                2023.540541          1.747748  117438.324324
# Research Engineer               2023.426523          2.573477  199292.508961
# Research Scientist              2023.391129          2.633065  196113.171371
#
#                                 remote_ratio  is_outlier
# job_title
# AI Engineer                        19.191919    0.595960
# Analytics Engineer                 44.189189    0.416216
# Applied Scientist                  25.934579    0.507009
# BI Developer                       28.767123    0.493151
# Business Intelligence              29.166667    0.364583
# Business Intelligence Analyst      34.177215    0.373418
# Business Intelligence Engineer     22.881356    0.665254
# Data Analyst                       36.934204    0.477368
# Data Analytics Manager             23.728814    0.322034
# Data Architect                     43.734015    0.437340
# Data Engineer                      31.544715    0.419837
# Data Manager                       14.583333    0.442708
# Data Modeler                       28.000000    0.400000
# Data Science                       22.580645    0.504032
# Data Science Consultant            12.676056    0.535211
# Data Science Manager               40.265487    0.637168
# Data Scientist                     33.950402    0.406916
# Data Specialist                    21.621622    0.594595
# ML Engineer                        32.203390    0.531073
# Machine Learning Engineer          24.136786    0.507968
# Machine Learning Scientist         31.465517    0.456897
# Research Analyst                   25.225225    0.495495
# Research Engineer                   8.960573    0.555556
# Research Scientist                 17.641129    0.542339

# %%
df = pd.get_dummies(df, columns=['job_title'])
#creamos de variables dummy

# %% [markdown]
# #### 5. Columna Employee_residence

# %%
# Cuenta los valores en los que las columnas company_location y employee_residence no coinciden
mismatch_count = (df['company_location'] != df['employee_residence']).sum()
mismatch_count
#casi todo el mundo vive donde trabaja, por lo cual la informacion esta repetida y puedo cargarme una columna
# Out:
# 24

# %%
df = df.drop(columns=['employee_residence'])

# %% [markdown]
# #### 6. Columna remote_ratio

# %%
df['remote_ratio'].value_counts()
# Out:
# remote_ratio
# 0      9275
# 100    4121
# 50       28
# Name: count, dtype: int64

# %% [markdown]
# #### 7. Columna Company_size

# %%
sns.boxplot(x='company_size', y='salary_in_usd', data=df)
#s=small, M=middle, L=large
#vemos que las empresas pequeñas se cobra menos pero entre mediana y grande apenas hay diferencia
# Out:
# <Axes: xlabel='company_size', ylabel='salary_in_usd'>

# %%
df.groupby('company_size').mean('salary_in_usd')
# Out:
#                 work_year  experience_level  salary_in_usd  remote_ratio  \
# company_size
# L             2022.904011          2.597421  164268.504298     18.839542
# M             2023.284813          2.673001  157139.890790     31.323924
# S             2021.863636          2.090909  107733.181818     70.454545
#
#               is_outlier  job_title_AI Engineer  job_title_Analytics Engineer  \
# company_size
# L               0.535817               0.000000                      0.002865
# M               0.454502               0.007727                      0.028939
# S               0.522727               0.022727                      0.022727
#
#               job_title_Applied Scientist  job_title_BI Developer  \
# company_size
# L                                0.353868                0.001433
# M                                0.014272                0.005677
# S                                0.000000                0.000000
#
#               job_title_Business Intelligence  ...  \
# company_size                                   ...
# L                                    0.002865  ...
# M                                    0.007412  ...
# S                                    0.000000  ...
#
#               job_title_Data Science Consultant  \
# company_size
# L                                      0.001433
# M                                      0.005441
# S                                      0.022727
#
#               job_title_Data Science Manager  job_title_Data Scientist  \
# company_size
# L                                   0.015759                  0.124642
# M                                   0.008043                  0.218026
# S                                   0.000000                  0.250000
#
#               job_title_Data Specialist  job_title_ML Engineer  \
# company_size
# L                              0.005731               0.010029
# M                              0.005520               0.013326
# S                              0.000000               0.022727
#
#               job_title_Machine Learning Engineer  \
# company_size
# L                                        0.054441
# M                                        0.115203
# S                                        0.159091
#
#               job_title_Machine Learning Scientist  \
# company_size
# L                                         0.004298
# M                                         0.008437
# S                                         0.136364
#
#               job_title_Research Analyst  job_title_Research Engineer  \
# company_size
# L                               0.005731                     0.002865
# M                               0.008358                     0.021842
# S                               0.022727                     0.000000
#
#               job_title_Research Scientist
# company_size
# L                                 0.057307
# M                                 0.035878
# S                                 0.022727
#
# [3 rows x 29 columns]

# %%
# Pasar la columna de str a int
df['company_size'] = df['company_size'].replace({'S': 1, 'M': 2, 'L': 2})
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_16264\69041577.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['company_size'] = df['company_size'].replace({'S': 1, 'M': 2, 'L': 2})

# %% [markdown]
# ### **Una vez que hemos limpiado la data vamos a ver la relaciones entre las variables**

# %%
# Crear el histograma con Seaborn
sns.histplot(df['salary_in_usd'], kde=True)

# Ajustar la escala del eje x y el eje y (opcional)
plt.xlim(0, 500000)  # Ajustar los valores según el rango de tus datos
plt.ylim(0, 1000)     # Ajustar los valores según el rango de tus datos

# Mostrar el gráfico
plt.show()

#vemos que la targer salary tiene una distribucion mas o menos normal, por lo que estaria ok para nuestro modelo

# %%
sns.lineplot(data=df, x='work_year', y='salary_in_usd', hue='experience_level')
#tendencia alcista en los salarios segun transcurren los años da igual tu nivel de experiencia
# Out:
# <Axes: xlabel='work_year', ylabel='salary_in_usd'>

# %%
df.head()
# Out:
#     work_year  experience_level  salary_in_usd  remote_ratio company_location  \
# 4        2024                 2         240000             0               US
# 5        2024                 2         180000             0               US
# 6        2024                 3         202800             0               US
# 7        2024                 3         115000             0               US
# 12       2024                 2         112300             0               US
#
#     company_size  is_outlier  job_title_AI Engineer  \
# 4              2           1                  False
# 5              2           1                  False
# 6              2           1                  False
# 7              2           1                  False
# 12             2           0                  False
#
#     job_title_Analytics Engineer  job_title_Applied Scientist  ...  \
# 4                          False                        False  ...
# 5                          False                        False  ...
# 6                          False                        False  ...
# 7                          False                        False  ...
# 12                         False                        False  ...
#
#     job_title_Data Science Consultant  job_title_Data Science Manager  \
# 4                               False                            True
# 5                               False                            True
# 6                               False                           False
# 7                               False                           False
# 12                              False                           False
#
#     job_title_Data Scientist  job_title_Data Specialist  \
# 4                      False                      False
# 5                      False                      False
# 6                      False                      False
# 7                      False                      False
# 12                     False                      False
#
#     job_title_ML Engineer  job_title_Machine Learning Engineer  \
# 4                   False                                False
# 5                   False                                False
# 6                   False                                False
# 7                   False                                False
# 12                  False                                False
#
#     job_title_Machine Learning Scientist  job_title_Research Analyst  \
# 4                                  False                       False
# 5                                  False                       False
# 6                                  False                       False
# 7                                  False                       False
# 12                                 False                       False
#
#     job_title_Research Engineer  job_title_Research Scientist
# 4                         False                         False
# 5                         False                         False
# 6                         False                         False
# 7                         False                         False
# 12                        False                         False
#
# [5 rows x 31 columns]

# %%
# Especificar las columnas que deseas incluir en el pairplot
columnas_a_incluir = ['experience_level', 'work_year','remote_ratio','company_size']

# Crear el pairplot con las columnas seleccionadas
sns.pairplot(df, vars=columnas_a_incluir, hue="salary_in_usd")

# Mostrar el gráfico
plt.show()

# %%
# Especificar las columnas que deseas incluir en la matriz de correlación
columnas_a_incluir = ['experience_level', 'work_year', 'salary_in_usd', 'remote_ratio', 'company_size']

# Filtrar el DataFrame para incluir solo las columnas seleccionadas
df_filtrado = df[columnas_a_incluir]

# Calcular la matriz de correlación
matriz_correlacion = df_filtrado.corr()

# Crear el heatmap con la matriz de correlación
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', vmin=-1, vmax=1)

#vemos que apenas hay correlacion lineal entre las variables, solo un poco entre años de experiencia y la ubicacion de la compañia
# Out:
# <Axes: >

# %%
# Calcula la matriz de correlación entre todas las columnas 
df.corr()
# Out:
#                                           work_year  experience_level  \
# work_year                                  1.000000         -0.133863
# experience_level                          -0.133863          1.000000
# salary_in_usd                              0.026247          0.306054
# remote_ratio                              -0.167866          0.061370
# company_size                               0.122200          0.051707
# is_outlier                                 0.035342          0.016750
# job_title_AI Engineer                      0.048119          0.008107
# job_title_Analytics Engineer              -0.010643          0.025026
# job_title_Applied Scientist                0.001014          0.010253
# job_title_BI Developer                    -0.000009         -0.024888
# job_title_Business Intelligence            0.095772         -0.000066
# job_title_Business Intelligence Analyst    0.053601         -0.081504
# job_title_Business Intelligence Engineer   0.016048          0.041286
# job_title_Data Analyst                    -0.014255         -0.208042
# job_title_Data Analytics Manager          -0.012647         -0.035881
# job_title_Data Architect                   0.004191          0.079808
# job_title_Data Engineer                   -0.080214          0.074190
# job_title_Data Manager                     0.003840         -0.025617
# job_title_Data Modeler                     0.020490          0.016536
# job_title_Data Science                     0.122746          0.028170
# job_title_Data Science Consultant          0.003941          0.018692
# job_title_Data Science Manager            -0.055258          0.014813
# job_title_Data Scientist                  -0.038399          0.040951
# job_title_Data Specialist                 -0.009619         -0.049385
# job_title_ML Engineer                      0.006892          0.015238
# job_title_Machine Learning Engineer        0.020133          0.092058
# job_title_Machine Learning Scientist       0.002209          0.012101
# job_title_Research Analyst                 0.039033         -0.131363
# job_title_Research Engineer                0.036935         -0.021357
# job_title_Research Scientist               0.039081         -0.010451
#
#                                           salary_in_usd  remote_ratio  \
# work_year                                      0.026247     -0.167866
# experience_level                               0.306054      0.061370
# salary_in_usd                                  1.000000     -0.042552
# remote_ratio                                  -0.042552      1.000000
# company_size                                   0.043704     -0.049312
# is_outlier                                     0.211212     -0.065577
# job_title_AI Engineer                          0.021181     -0.021704
# job_title_Analytics Engineer                   0.017113      0.048874
# job_title_Applied Scientist                    0.093516     -0.019160
# job_title_BI Developer                        -0.049267     -0.003265
# job_title_Business Intelligence               -0.017641     -0.003012
# job_title_Business Intelligence Analyst       -0.059397      0.007986
# job_title_Business Intelligence Engineer      -0.028831     -0.022981
# job_title_Data Analyst                        -0.303562      0.057952
# job_title_Data Analytics Manager              -0.019664     -0.010193
# job_title_Data Architect                       0.022513      0.048572
# job_title_Data Engineer                       -0.034602      0.008768
# job_title_Data Manager                        -0.085572     -0.042371
# job_title_Data Modeler                        -0.021644     -0.003717
# job_title_Data Science                         0.025691     -0.024464
# job_title_Data Science Consultant             -0.046567     -0.028665
# job_title_Data Science Manager                 0.062194      0.018907
# job_title_Data Scientist                       0.044531      0.035538
# job_title_Data Specialist                     -0.070764     -0.014824
# job_title_ML Engineer                          0.076593      0.003510
# job_title_Machine Learning Engineer            0.209670     -0.051391
# job_title_Machine Learning Scientist           0.053868      0.001341
# job_title_Research Analyst                    -0.055978     -0.011045
# job_title_Research Engineer                    0.093864     -0.069010
# job_title_Research Scientist                   0.116632     -0.055910
#
#                                           company_size  is_outlier  \
# work_year                                     0.122200    0.035342
# experience_level                              0.051707    0.016750
# salary_in_usd                                 0.043704    0.211212
# remote_ratio                                 -0.049312   -0.065577
# company_size                                  1.000000   -0.007339
# is_outlier                                   -0.007339    1.000000
# job_title_AI Engineer                        -0.010290    0.023698
# job_title_Analytics Engineer                  0.001694   -0.014439
# job_title_Applied Scientist                   0.010407    0.017501
# job_title_BI Developer                        0.004240    0.005074
# job_title_Business Intelligence               0.004867   -0.016073
# job_title_Business Intelligence Analyst       0.006258   -0.018733
# job_title_Business Intelligence Engineer      0.007671    0.055381
# job_title_Data Analyst                       -0.017706    0.016106
# job_title_Data Analytics Manager              0.003810   -0.018256
# job_title_Data Architect                      0.009933   -0.007513
# job_title_Data Engineer                       0.025056   -0.042789
# job_title_Data Manager                        0.006908   -0.003927
# job_title_Data Modeler                        0.003506   -0.007234
# job_title_Data Science                        0.007867    0.012411
# job_title_Data Science Consultant            -0.013787    0.011159
# job_title_Data Science Manager                0.005284    0.032951
# job_title_Data Scientist                     -0.005141   -0.054373
# job_title_Data Specialist                     0.004269    0.020266
# job_title_ML Engineer                        -0.004797    0.016729
# job_title_Machine Learning Engineer          -0.008523    0.034965
# job_title_Machine Learning Scientist         -0.079134   -0.000385
# job_title_Research Analyst                   -0.009156    0.006696
# job_title_Research Engineer                   0.008354    0.028243
# job_title_Research Scientist                  0.004323    0.032776
#
#                                           job_title_AI Engineer  \
# work_year                                              0.048119
# experience_level                                       0.008107
# salary_in_usd                                          0.021181
# remote_ratio                                          -0.021704
# company_size                                          -0.010290
# is_outlier                                             0.023698
# job_title_AI Engineer                                  1.000000
# job_title_Analytics Engineer                          -0.014512
# job_title_Applied Scientist                           -0.015642
# job_title_BI Developer                                -0.006374
# job_title_Business Intelligence                       -0.007315
# job_title_Business Intelligence Analyst               -0.009407
# job_title_Business Intelligence Engineer              -0.011531
# job_title_Data Analyst                                -0.037568
# job_title_Data Analytics Manager                      -0.005727
# job_title_Data Architect                              -0.014930
# job_title_Data Engineer                               -0.046985
# job_title_Data Manager                                -0.010383
# job_title_Data Modeler                                -0.005270
# job_title_Data Science                                -0.011825
# job_title_Data Science Consultant                     -0.006285
# job_title_Data Science Manager                        -0.007942
# job_title_Data Scientist                              -0.044879
# job_title_Data Specialist                             -0.006417
# job_title_ML Engineer                                 -0.009963
# job_title_Machine Learning Engineer                   -0.030640
# job_title_Machine Learning Scientist                  -0.008047
# job_title_Research Analyst                            -0.007871
# job_title_Research Engineer                           -0.012558
# job_title_Research Scientist                          -0.016883
#
#                                           job_title_Analytics Engineer  \
# work_year                                                    -0.010643
# experience_level                                              0.025026
# salary_in_usd                                                 0.017113
# remote_ratio                                                  0.048874
# company_size                                                  0.001694
# is_outlier                                                   -0.014439
# job_title_AI Engineer                                        -0.014512
# job_title_Analytics Engineer                                  1.000000
# job_title_Applied Scientist                                  -0.030552
# job_title_BI Developer                                       -0.012449
# job_title_Business Intelligence                              -0.014288
# job_title_Business Intelligence Analyst                      -0.018373
# job_title_Business Intelligence Engineer                     -0.022521
# job_title_Data Analyst                                       -0.073378
# job_title_Data Analytics Manager                             -0.011186
# job_title_Data Architect                                     -0.029161
# job_title_Data Engineer                                      -0.091770
# job_title_Data Manager                                       -0.020280
# job_title_Data Modeler                                       -0.010294
# job_title_Data Science                                       -0.023097
# job_title_Data Science Consultant                            -0.012276
# job_title_Data Science Manager                               -0.015512
# job_title_Data Scientist                                     -0.087657
# job_title_Data Specialist                                    -0.012534
# job_title_ML Engineer                                        -0.019461
# job_title_Machine Learning Engineer                          -0.059847
# job_title_Machine Learning Scientist                         -0.015718
# job_title_Research Analyst                                   -0.015373
# job_title_Research Engineer                                  -0.024527
# job_title_Research Scientist                                 -0.032976
#
#                                           job_title_Applied Scientist  \
# work_year                                                    0.001014
# experience_level                                             0.010253
# salary_in_usd                                                0.093516
# remote_ratio                                                -0.019160
# company_size                                                 0.010407
# is_outlier                                                   0.017501
# job_title_AI Engineer                                       -0.015642
# job_title_Analytics Engineer                                -0.030552
# job_title_Applied Scientist                                  1.000000
# job_title_BI Developer                                      -0.013419
# job_title_Business Intelligence                             -0.015402
# job_title_Business Intelligence Analyst                     -0.019805
# job_title_Business Intelligence Engineer                    -0.024276
# job_title_Data Analyst                                      -0.079096
# job_title_Data Analytics Manager                            -0.012058
# job_title_Data Architect                                    -0.031433
# job_title_Data Engineer                                     -0.098921
# job_title_Data Manager                                      -0.021860
# job_title_Data Modeler                                      -0.011096
# job_title_Data Science                                      -0.024897
# job_title_Data Science Consultant                           -0.013233
# job_title_Data Science Manager                              -0.016721
# job_title_Data Scientist                                    -0.094488
# job_title_Data Specialist                                   -0.013511
# job_title_ML Engineer                                       -0.020977
# job_title_Machine Learning Engineer                         -0.064510
# job_title_Machine Learning Scientist                        -0.016943
# job_title_Research Analyst                                  -0.016571
# job_title_Research Engineer                                 -0.026439
# job_title_Research Scientist                                -0.035546
#
#                                           job_title_BI Developer  ...  \
# work_year                                              -0.000009  ...
# experience_level                                       -0.024888  ...
# salary_in_usd                                          -0.049267  ...
# remote_ratio                                           -0.003265  ...
# company_size                                            0.004240  ...
# is_outlier                                              0.005074  ...
# job_title_AI Engineer                                  -0.006374  ...
# job_title_Analytics Engineer                           -0.012449  ...
# job_title_Applied Scientist                            -0.013419  ...
# job_title_BI Developer                                  1.000000  ...
# job_title_Business Intelligence                        -0.006276  ...
# job_title_Business Intelligence Analyst                -0.008070  ...
# job_title_Business Intelligence Engineer               -0.009892  ...
# job_title_Data Analyst                                 -0.032229  ...
# job_title_Data Analytics Manager                       -0.004913  ...
# job_title_Data Architect                               -0.012808  ...
# job_title_Data Engineer                                -0.040307  ...
# job_title_Data Manager                                 -0.008907  ...
# job_title_Data Modeler                                 -0.004521  ...
# job_title_Data Science                                 -0.010145  ...
# job_title_Data Science Consultant                      -0.005392  ...
# job_title_Data Science Manager                         -0.006813  ...
# job_title_Data Scientist                               -0.038500  ...
# job_title_Data Specialist                              -0.005505  ...
# job_title_ML Engineer                                  -0.008547  ...
# job_title_Machine Learning Engineer                    -0.026285  ...
# job_title_Machine Learning Scientist                   -0.006904  ...
# job_title_Research Analyst                             -0.006752  ...
# job_title_Research Engineer                            -0.010773  ...
# job_title_Research Scientist                           -0.014484  ...
#
#                                           job_title_Data Science Consultant  \
# work_year                                                          0.003941
# experience_level                                                   0.018692
# salary_in_usd                                                     -0.046567
# remote_ratio                                                      -0.028665
# company_size                                                      -0.013787
# is_outlier                                                         0.011159
# job_title_AI Engineer                                             -0.006285
# job_title_Analytics Engineer                                      -0.012276
# job_title_Applied Scientist                                       -0.013233
# job_title_BI Developer                                            -0.005392
# job_title_Business Intelligence                                   -0.006189
# job_title_Business Intelligence Analyst                           -0.007958
# job_title_Business Intelligence Engineer                          -0.009755
# job_title_Data Analyst                                            -0.031782
# job_title_Data Analytics Manager                                  -0.004845
# job_title_Data Architect                                          -0.012630
# job_title_Data Engineer                                           -0.039748
# job_title_Data Manager                                            -0.008784
# job_title_Data Modeler                                            -0.004459
# job_title_Data Science                                            -0.010004
# job_title_Data Science Consultant                                  1.000000
# job_title_Data Science Manager                                    -0.006719
# job_title_Data Scientist                                          -0.037966
# job_title_Data Specialist                                         -0.005429
# job_title_ML Engineer                                             -0.008429
# job_title_Machine Learning Engineer                               -0.025921
# job_title_Machine Learning Scientist                              -0.006808
# job_title_Research Analyst                                        -0.006658
# job_title_Research Engineer                                       -0.010623
# job_title_Research Scientist                                      -0.014283
#
#                                           job_title_Data Science Manager  \
# work_year                                                      -0.055258
# experience_level                                                0.014813
# salary_in_usd                                                   0.062194
# remote_ratio                                                    0.018907
# company_size                                                    0.005284
# is_outlier                                                      0.032951
# job_title_AI Engineer                                          -0.007942
# job_title_Analytics Engineer                                   -0.015512
# job_title_Applied Scientist                                    -0.016721
# job_title_BI Developer                                         -0.006813
# job_title_Business Intelligence                                -0.007820
# job_title_Business Intelligence Analyst                        -0.010055
# job_title_Business Intelligence Engineer                       -0.012325
# job_title_Data Analyst                                         -0.040158
# job_title_Data Analytics Manager                               -0.006122
# job_title_Data Architect                                       -0.015959
# job_title_Data Engineer                                        -0.050224
# job_title_Data Manager                                         -0.011099
# job_title_Data Modeler                                         -0.005634
# job_title_Data Science                                         -0.012641
# job_title_Data Science Consultant                              -0.006719
# job_title_Data Science Manager                                  1.000000
# job_title_Data Scientist                                       -0.047972
# job_title_Data Specialist                                      -0.006860
# job_title_ML Engineer                                          -0.010650
# job_title_Machine Learning Engineer                            -0.032753
# job_title_Machine Learning Scientist                           -0.008602
# job_title_Research Analyst                                     -0.008413
# job_title_Research Engineer                                    -0.013423
# job_title_Research Scientist                                   -0.018047
#
#                                           job_title_Data Scientist  \
# work_year                                                -0.038399
# experience_level                                          0.040951
# salary_in_usd                                             0.044531
# remote_ratio                                              0.035538
# company_size                                             -0.005141
# is_outlier                                               -0.054373
# job_title_AI Engineer                                    -0.044879
# job_title_Analytics Engineer                             -0.087657
# job_title_Applied Scientist                              -0.094488
# job_title_BI Developer                                   -0.038500
# job_title_Business Intelligence                          -0.044189
# job_title_Business Intelligence Analyst                  -0.056822
# job_title_Business Intelligence Engineer                 -0.069651
# job_title_Data Analyst                                   -0.226932
# job_title_Data Analytics Manager                         -0.034594
# job_title_Data Architect                                 -0.090183
# job_title_Data Engineer                                  -0.283813
# job_title_Data Manager                                   -0.062719
# job_title_Data Modeler                                   -0.031836
# job_title_Data Science                                   -0.071432
# job_title_Data Science Consultant                        -0.037966
# job_title_Data Science Manager                           -0.047972
# job_title_Data Scientist                                  1.000000
# job_title_Data Specialist                                -0.038764
# job_title_ML Engineer                                    -0.060185
# job_title_Machine Learning Engineer                      -0.185084
# job_title_Machine Learning Scientist                     -0.048611
# job_title_Research Analyst                               -0.047542
# job_title_Research Engineer                              -0.075854
# job_title_Research Scientist                             -0.101984
#
#                                           job_title_Data Specialist  \
# work_year                                                 -0.009619
# experience_level                                          -0.049385
# salary_in_usd                                             -0.070764
# remote_ratio                                              -0.014824
# company_size                                               0.004269
# is_outlier                                                 0.020266
# job_title_AI Engineer                                     -0.006417
# job_title_Analytics Engineer                              -0.012534
# job_title_Applied Scientist                               -0.013511
# job_title_BI Developer                                    -0.005505
# job_title_Business Intelligence                           -0.006319
# job_title_Business Intelligence Analyst                   -0.008125
# job_title_Business Intelligence Engineer                  -0.009960
# job_title_Data Analyst                                    -0.032450
# job_title_Data Analytics Manager                          -0.004947
# job_title_Data Architect                                  -0.012896
# job_title_Data Engineer                                   -0.040583
# job_title_Data Manager                                    -0.008968
# job_title_Data Modeler                                    -0.004552
# job_title_Data Science                                    -0.010214
# job_title_Data Science Consultant                         -0.005429
# job_title_Data Science Manager                            -0.006860
# job_title_Data Scientist                                  -0.038764
# job_title_Data Specialist                                  1.000000
# job_title_ML Engineer                                     -0.008606
# job_title_Machine Learning Engineer                       -0.026466
# job_title_Machine Learning Scientist                      -0.006951
# job_title_Research Analyst                                -0.006798
# job_title_Research Engineer                               -0.010847
# job_title_Research Scientist                              -0.014583
#
#                                           job_title_ML Engineer  \
# work_year                                              0.006892
# experience_level                                       0.015238
# salary_in_usd                                          0.076593
# remote_ratio                                           0.003510
# company_size                                          -0.004797
# is_outlier                                             0.016729
# job_title_AI Engineer                                 -0.009963
# job_title_Analytics Engineer                          -0.019461
# job_title_Applied Scientist                           -0.020977
# job_title_BI Developer                                -0.008547
# job_title_Business Intelligence                       -0.009810
# job_title_Business Intelligence Analyst               -0.012615
# job_title_Business Intelligence Engineer              -0.015463
# job_title_Data Analyst                                -0.050381
# job_title_Data Analytics Manager                      -0.007680
# job_title_Data Architect                              -0.020021
# job_title_Data Engineer                               -0.063009
# job_title_Data Manager                                -0.013924
# job_title_Data Modeler                                -0.007068
# job_title_Data Science                                -0.015858
# job_title_Data Science Consultant                     -0.008429
# job_title_Data Science Manager                        -0.010650
# job_title_Data Scientist                              -0.060185
# job_title_Data Specialist                             -0.008606
# job_title_ML Engineer                                  1.000000
# job_title_Machine Learning Engineer                   -0.041090
# job_title_Machine Learning Scientist                  -0.010792
# job_title_Research Analyst                            -0.010555
# job_title_Research Engineer                           -0.016840
# job_title_Research Scientist                          -0.022641
#
#                                           job_title_Machine Learning Engineer  \
# work_year                                                            0.020133
# experience_level                                                     0.092058
# salary_in_usd                                                        0.209670
# remote_ratio                                                        -0.051391
# company_size                                                        -0.008523
# is_outlier                                                           0.034965
# job_title_AI Engineer                                               -0.030640
# job_title_Analytics Engineer                                        -0.059847
# job_title_Applied Scientist                                         -0.064510
# job_title_BI Developer                                              -0.026285
# job_title_Business Intelligence                                     -0.030169
# job_title_Business Intelligence Analyst                             -0.038794
# job_title_Business Intelligence Engineer                            -0.047553
# job_title_Data Analyst                                              -0.154934
# job_title_Data Analytics Manager                                    -0.023619
# job_title_Data Architect                                            -0.061571
# job_title_Data Engineer                                             -0.193769
# job_title_Data Manager                                              -0.042820
# job_title_Data Modeler                                              -0.021735
# job_title_Data Science                                              -0.048769
# job_title_Data Science Consultant                                   -0.025921
# job_title_Data Science Manager                                      -0.032753
# job_title_Data Scientist                                            -0.185084
# job_title_Data Specialist                                           -0.026466
# job_title_ML Engineer                                               -0.041090
# job_title_Machine Learning Engineer                                  1.000000
# job_title_Machine Learning Scientist                                -0.033188
# job_title_Research Analyst                                          -0.032459
# job_title_Research Engineer                                         -0.051788
# job_title_Research Scientist                                        -0.069628
#
#                                           job_title_Machine Learning Scientist  \
# work_year                                                             0.002209
# experience_level                                                      0.012101
# salary_in_usd                                                         0.053868
# remote_ratio                                                          0.001341
# company_size                                                         -0.079134
# is_outlier                                                           -0.000385
# job_title_AI Engineer                                                -0.008047
# job_title_Analytics Engineer                                         -0.015718
# job_title_Applied Scientist                                          -0.016943
# job_title_BI Developer                                               -0.006904
# job_title_Business Intelligence                                      -0.007924
# job_title_Business Intelligence Analyst                              -0.010189
# job_title_Business Intelligence Engineer                             -0.012489
# job_title_Data Analyst                                               -0.040692
# job_title_Data Analytics Manager                                     -0.006203
# job_title_Data Architect                                             -0.016171
# job_title_Data Engineer                                              -0.050892
# job_title_Data Manager                                               -0.011246
# job_title_Data Modeler                                               -0.005709
# job_title_Data Science                                               -0.012809
# job_title_Data Science Consultant                                    -0.006808
# job_title_Data Science Manager                                       -0.008602
# job_title_Data Scientist                                             -0.048611
# job_title_Data Specialist                                            -0.006951
# job_title_ML Engineer                                                -0.010792
# job_title_Machine Learning Engineer                                  -0.033188
# job_title_Machine Learning Scientist                                  1.000000
# job_title_Research Analyst                                           -0.008525
# job_title_Research Engineer                                          -0.013602
# job_title_Research Scientist                                         -0.018287
#
#                                           job_title_Research Analyst  \
# work_year                                                   0.039033
# experience_level                                           -0.131363
# salary_in_usd                                              -0.055978
# remote_ratio                                               -0.011045
# company_size                                               -0.009156
# is_outlier                                                  0.006696
# job_title_AI Engineer                                      -0.007871
# job_title_Analytics Engineer                               -0.015373
# job_title_Applied Scientist                                -0.016571
# job_title_BI Developer                                     -0.006752
# job_title_Business Intelligence                            -0.007750
# job_title_Business Intelligence Analyst                    -0.009965
# job_title_Business Intelligence Engineer                   -0.012215
# job_title_Data Analyst                                     -0.039798
# job_title_Data Analytics Manager                           -0.006067
# job_title_Data Architect                                   -0.015816
# job_title_Data Engineer                                    -0.049773
# job_title_Data Manager                                     -0.010999
# job_title_Data Modeler                                     -0.005583
# job_title_Data Science                                     -0.012527
# job_title_Data Science Consultant                          -0.006658
# job_title_Data Science Manager                             -0.008413
# job_title_Data Scientist                                   -0.047542
# job_title_Data Specialist                                  -0.006798
# job_title_ML Engineer                                      -0.010555
# job_title_Machine Learning Engineer                        -0.032459
# job_title_Machine Learning Scientist                       -0.008525
# job_title_Research Analyst                                  1.000000
# job_title_Research Engineer                                -0.013303
# job_title_Research Scientist                               -0.017885
#
#                                           job_title_Research Engineer  \
# work_year                                                    0.036935
# experience_level                                            -0.021357
# salary_in_usd                                                0.093864
# remote_ratio                                                -0.069010
# company_size                                                 0.008354
# is_outlier                                                   0.028243
# job_title_AI Engineer                                       -0.012558
# job_title_Analytics Engineer                                -0.024527
# job_title_Applied Scientist                                 -0.026439
# job_title_BI Developer                                      -0.010773
# job_title_Business Intelligence                             -0.012364
# job_title_Business Intelligence Analyst                     -0.015899
# job_title_Business Intelligence Engineer                    -0.019489
# job_title_Data Analyst                                      -0.063498
# job_title_Data Analytics Manager                            -0.009680
# job_title_Data Architect                                    -0.025234
# job_title_Data Engineer                                     -0.079414
# job_title_Data Manager                                      -0.017549
# job_title_Data Modeler                                      -0.008908
# job_title_Data Science                                      -0.019987
# job_title_Data Science Consultant                           -0.010623
# job_title_Data Science Manager                              -0.013423
# job_title_Data Scientist                                    -0.075854
# job_title_Data Specialist                                   -0.010847
# job_title_ML Engineer                                       -0.016840
# job_title_Machine Learning Engineer                         -0.051788
# job_title_Machine Learning Scientist                        -0.013602
# job_title_Research Analyst                                  -0.013303
# job_title_Research Engineer                                  1.000000
# job_title_Research Scientist                                -0.028536
#
#                                           job_title_Research Scientist
# work_year                                                     0.039081
# experience_level                                             -0.010451
# salary_in_usd                                                 0.116632
# remote_ratio                                                 -0.055910
# company_size                                                  0.004323
# is_outlier                                                    0.032776
# job_title_AI Engineer                                        -0.016883
# job_title_Analytics Engineer                                 -0.032976
# job_title_Applied Scientist                                  -0.035546
# job_title_BI Developer                                       -0.014484
# job_title_Business Intelligence                              -0.016624
# job_title_Business Intelligence Analyst                      -0.021376
# job_title_Business Intelligence Engineer                     -0.026202
# job_title_Data Analyst                                       -0.085371
# job_title_Data Analytics Manager                             -0.013014
# job_title_Data Architect                                     -0.033927
# job_title_Data Engineer                                      -0.106770
# job_title_Data Manager                                       -0.023595
# job_title_Data Modeler                                       -0.011976
# job_title_Data Science                                       -0.026873
# job_title_Data Science Consultant                            -0.014283
# job_title_Data Science Manager                               -0.018047
# job_title_Data Scientist                                     -0.101984
# job_title_Data Specialist                                    -0.014583
# job_title_ML Engineer                                        -0.022641
# job_title_Machine Learning Engineer                          -0.069628
# job_title_Machine Learning Scientist                         -0.018287
# job_title_Research Analyst                                   -0.017885
# job_title_Research Engineer                                  -0.028536
# job_title_Research Scientist                                  1.000000
#
# [30 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2857 entries, 13812 to 16478
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   work_year                                2857 non-null   int64
#  1   experience_level                         2857 non-null   int64
#  2   salary_in_usd                            2857 non-null   int64
#  3   remote_ratio                             2857 non-null   int64
#  4   company_location                         2857 non-null   int64
#  5   company_size                             2857 non-null   int64
#  6   is_outlier                               2857 non-null   int32
#  7   job_title_Analytics Engineer             2857 non-null   bool
#  8   job_title_Applied Scientist              2857 non-null   bool
#  9   job_title_Business Intelligence Analyst  2857 non-null   bool
#  10  job_title_Data Analyst                   2857 non-null   bool
#  11  job_title_Data Architect                 2857 non-null   bool
#  12  job_title_Data Engineer                  2857 non-null   bool
#  13  job_title_Data Science                   2857 non-null   bool
#  14  job_title_Data Scientist                 2857 non-null   bool
#  15  job_title_Machine Learning Engineer      2857 non-null   bool
#  16  job_title_Research Scientist             2857 non-null   bool
# dtypes: bool(10), int32(1), int64(6)
# memory usage: 195.3 KB

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\juanc\appdata\local\programs\python\python312\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\juanc\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\juanc\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.13.0)

# %%
import xgboost

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import 
from xgboost import XGBRegressor
# Out:
#   Cell In[46], line 4
#     import
#            ^
# SyntaxError: invalid syntax

# %%
# Dividir los datos en variables predictoras (X) y variable objetivo (y)
X = df.drop(columns=['salary_in_usd'])
y = df['salary_in_usd']

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ### **XGBoost**

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

# XGBoost
from xgboost import XGBRegressor

# Crear y ajustar el modelo XGBoost
xgboost_model = XGBRegressor(n_estimators=100, random_state=0)
xgboost_model.fit(X, y)

# Calcular el error absoluto medio en el conjunto de entrenamiento
mae_train = mean_absolute_error(y, xgboost_model.predict(X))
print(f"Mean Absolute Error on Training Set: {mae_train}")

# Calcular el error absoluto medio en porcentaje
mae_train_percentage = (mae_train / y.mean()) * 100
print(f"Mean Absolute Error on Training Set (Percentage): {mae_train_percentage:.2f}%")

# Validación cruzada para evaluar el modelo
xgboost_mae_scores = -cross_val_score(xgboost_model, X, y, cv=10, scoring='neg_mean_absolute_error')
mean_mae_cv = xgboost_mae_scores.mean()
print(f"Mean Absolute Error with Cross Validation: {mean_mae_cv}")

# Calcular el MAE en porcentaje para validación cruzada
mean_mae_cv_percentage = (mean_mae_cv / y.mean()) * 100
print(f"Mean Absolute Error with Cross Validation (Percentage): {mean_mae_cv_percentage:.2f}%")
# Out:
# Mean Absolute Error on Training Set: 32369.398379883976
# Mean Absolute Error on Training Set (Percentage): 20.57%
# Mean Absolute Error with Cross Validation: 34619.26119708801
# Mean Absolute Error with Cross Validation (Percentage): 22.00%

# %% [markdown]
# ### **RandomForest**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

# Crear y ajustar el modelo Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=0)
rf_model.fit(X, y)

# Calcular el error absoluto medio en el conjunto de entrenamiento
mae_train_rf = mean_absolute_error(y, rf_model.predict(X))
print(f"Mean Absolute Error on Training Set (Random Forest): {mae_train_rf}")

# Calcular el error absoluto medio en porcentaje en el conjunto de entrenamiento
mae_train_rf_percentage = (mae_train_rf / y.mean()) * 100
print(f"Mean Absolute Error on Training Set (Random Forest, Percentage): {mae_train_rf_percentage:.2f}%")

# Validación cruzada para evaluar el modelo
rf_mae_scores = -cross_val_score(rf_model, X, y, cv=10, scoring='neg_mean_absolute_error')
mean_mae_cv_rf = rf_mae_scores.mean()
print(f"Mean Absolute Error with Cross Validation (Random Forest): {mean_mae_cv_rf}")

# Calcular el MAE en porcentaje para validación cruzada
mean_mae_cv_rf_percentage = (mean_mae_cv_rf / y.mean()) * 100
print(f"Mean Absolute Error with Cross Validation (Random Forest, Percentage): {mean_mae_cv_rf_percentage:.2f}%")
# Out:
# Mean Absolute Error on Training Set (Random Forest): 32379.833391127435
# Mean Absolute Error on Training Set (Random Forest, Percentage): 20.58%
# Mean Absolute Error with Cross Validation (Random Forest): 34558.79556941895
# Mean Absolute Error with Cross Validation (Random Forest, Percentage): 21.96%

# %% [markdown]
# ### **Regresion Lineal**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

# Crear y ajustar el modelo de regresión lineal
linear_model = LinearRegression()
linear_model.fit(X, y)

# Calcular el error absoluto medio en el conjunto de entrenamiento
mae_train_linear = mean_absolute_error(y, linear_model.predict(X))
print(f"Mean Absolute Error on Training Set (Linear Regression): {mae_train_linear}")

# Calcular el error absoluto medio en porcentaje en el conjunto de entrenamiento
mae_train_linear_percentage = (mae_train_linear / y.mean()) * 100
print(f"Mean Absolute Error on Training Set (Linear Regression, Percentage): {mae_train_linear_percentage:.2f}%")

# Validación cruzada para evaluar el modelo
linear_mae_scores = -cross_val_score(linear_model, X, y, cv=10, scoring='neg_mean_absolute_error')
mean_mae_cv_linear = linear_mae_scores.mean()
print(f"Mean Absolute Error with Cross Validation (Linear Regression): {mean_mae_cv_linear}")

# Calcular el MAE en porcentaje para validación cruzada
mean_mae_cv_linear_percentage = (mean_mae_cv_linear / y.mean()) * 100
print(f"Mean Absolute Error with Cross Validation (Linear Regression, Percentage): {mean_mae_cv_linear_percentage:.2f}%")
# Out:
# Mean Absolute Error on Training Set (Linear Regression): 39936.48373412434
# Mean Absolute Error on Training Set (Linear Regression, Percentage): 25.38%
# Mean Absolute Error with Cross Validation (Linear Regression): 40166.74329742589
# Mean Absolute Error with Cross Validation (Linear Regression, Percentage): 25.53%

# %% [markdown]
# ### **Polinomica 2**

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

# Crear características polinómicas de grado 2
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)

# Crear y ajustar un modelo de regresión lineal
linear_model_poly_degree_2 = LinearRegression()
linear_model_poly_degree_2.fit(X_poly, y)

# Calcular el error absoluto medio en el conjunto de entrenamiento
mae_train_linear_poly_degree_2 = mean_absolute_error(y, linear_model_poly_degree_2.predict(X_poly))
print(f"Mean Absolute Error on Training Set (Polynomial Linear Regression - Degree 2): {mae_train_linear_poly_degree_2}")

# Calcular el error absoluto medio en porcentaje en el conjunto de entrenamiento
mae_train_linear_poly_degree_2_percentage = (mae_train_linear_poly_degree_2 / y.mean()) * 100
print(f"Mean Absolute Error on Training Set (Polynomial Linear Regression - Degree 2, Percentage): {mae_train_linear_poly_degree_2_percentage:.2f}%")

# Validación cruzada para evaluar el modelo
linear_poly_mae_scores_degree_2 = -cross_val_score(linear_model_poly_degree_2, X_poly, y, cv=10, scoring='neg_mean_absolute_error')
mean_mae_cv_linear_poly_degree_2 = linear_poly_mae_scores_degree_2.mean()
print(f"Mean Absolute Error with Cross Validation (Polynomial Linear Regression - Degree 2): {mean_mae_cv_linear_poly_degree_2}")

# Calcular el MAE en porcentaje para validación cruzada
mean_mae_cv_linear_poly_degree_2_percentage = (mean_mae_cv_linear_poly_degree_2 / y.mean()) * 100
print(f"Mean Absolute Error with Cross Validation (Polynomial Linear Regression - Degree 2, Percentage): {mean_mae_cv_linear_poly_degree_2_percentage:.2f}%")
# Out:
# Mean Absolute Error on Training Set (Polynomial Linear Regression - Degree 2): 34092.73859656323
# Mean Absolute Error on Training Set (Polynomial Linear Regression - Degree 2, Percentage): 21.67%
# Mean Absolute Error with Cross Validation (Polynomial Linear Regression - Degree 2): 40255.51639061122
# Mean Absolute Error with Cross Validation (Polynomial Linear Regression - Degree 2, Percentage): 25.58%
